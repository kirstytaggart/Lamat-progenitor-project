# %%
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import math
from astropy.modeling.models import Ellipse2D
from matplotlib.patches import Circle
from matplotlib.patches import Ellipse
from astropy.coordinates import Angle
from regions import PixCoord, EllipsePixelRegion
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
from astropy.wcs import WCS
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.visualization import SqrtStretch
from matplotlib.patches import FancyArrowPatch
from scipy.optimize import minimize_scalar
# %matplotlib inline
from matplotlib.patches import Circle
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.axes_size import Fixed, Scaled
from matplotlib.gridspec import GridSpec
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogLocator
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.visualization.wcsaxes import SphericalCircle
from astropy.visualization.wcsaxes import Quadrangle
from matplotlib.patches import Rectangle
from astropy.nddata import Cutout2D

pgf_with_latex = {                      # setup matplotlib to use latex for output
    "pgf.texsystem": "pdflatex",        # change this if using xetex or lautex
    "text.usetex": True,                # use LaTeX to write all text
    "font.family": "serif",
    "font.serif": [],                   # blank entries should cause plots to inherit fonts from the document
    "font.sans-serif": [],
    "font.monospace": [],              # LaTeX default is 10pt font.            # Make the legend/label fonts a little smaller
    "pgf.preamble": r"\usepackage[ut f8x]{inputenc} \usepackage[T1]{fontenc}"   
}
 # use utf8 fonts becasue your computer can handle it :)
     # plots will be generated using this preamble
mpl.rcParams.update(pgf_with_latex)

#mpl.rcParams.keys()

# %%
path="C:\\Users\\domdo\\Lamat\\Foley\\sjt_trilogy_progenitor\\"
#path="/Users/kirstytaggart/Lamat/"
img='2021sjt_progenitor_RGB.fits'
wcs_img='ieb338010_drc.fits'
img_hst = get_pkg_data_filename(path+img)
img_wcs = get_pkg_data_filename(path+wcs_img)
fits.info(img_hst), fits.info(img_wcs)
# Out:
# Filename: C:\Users\domdo\Lamat\Foley\sjt_trilogy_progenitor\2021sjt_progenitor_RGB.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 ImageHDU         7   (4127, 4386)   uint8
#   2                1 ImageHDU         7   (4127, 4386)   uint8
#   3                1 ImageHDU         7   (4127, 4386)   uint8
# Filename: C:\Users\domdo\Lamat\Foley\sjt_trilogy_progenitor\ieb338010_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     857   ()
#   1  SCI           1 ImageHDU        92   (4127, 4386)   float32
#   2  WHT           1 ImageHDU        45   (4127, 4386)   float32
#   3  CTX           1 ImageHDU        40   (4127, 4386)   int32
# ...

# %%
hdu_img1 = fits.open(img_hst)[1]
hdu_img2 = fits.open(img_hst)[2]
hdu_img3 = fits.open(img_hst)[3]

data1=hdu_img1.data
data2=hdu_img2.data
data3=hdu_img3.data

hdu_wcs = fits.open(img_wcs)[1]

# %%
wcs = WCS(hdu_wcs.header)
stack=np.dstack((data1,data2,data3))

# %%
#distance to NGC6951 is 23.250 Mpc

def angle_to_size(angle, distance):
    size = (float(distance) * float(angle))/206265
    return size
    

def compass(self, x, y, size, color,fontsize):
        """Add a compass to indicate the north and east directions.
        Parameters
        ----------
        x, y : float
            Position of compass vertex in axes coordinates.
        size : float
            Size of compass in axes coordinates.
        fontsize: float
            Size of the N and S labels
        color: string 
            color of the scale bar, and the font
        """
        xy = x, y
        
        scale = self.wcs.pixel_scale_matrix
        scale /= np.sqrt(np.abs(np.linalg.det(scale)))
        return ([self.annotate(label, xy, xy + size * n, self.transAxes, self.transAxes, color=color,ha='center', \
        va='center',fontsize=fontsize,arrowprops=dict(color=color,arrowstyle='<-', shrinkA=0.0, shrinkB=0.0))
                for n, label, ha, va in zip(scale, 'EN',['right', 'center'],['center', 'bottom'])])
class ScaleBar(FancyArrowPatch):
    def _func(self, dx, x, y):
        p1, p2 = self._transAxesToWorld.transform([[x, y], [x + dx, y]])
        p1 = SkyCoord(*p1, unit=u.deg)
        p2 = SkyCoord(*p2, unit=u.deg)
        return np.square((p1.separation(p2) - self._length).value)
    def __init__(self, ax, xy, length, distance, color, *args, **kwargs):
        x, y = xy
        self._ax = ax
        self._length = u.Quantity(length)
        self._distance = u.Quantity(distance)
        self._transAxesToWorld = (
            (ax.transAxes - ax.transData) + ax.coords.frame.transform)
        dx = minimize_scalar(self._func, args=xy, bounds=[0, 1 - x], method='bounded').x
        custom_kwargs = kwargs
        kwargs = dict(
            capstyle='round',
            color=color,
            linewidth=mpl.rcParams['lines.linewidth'],
        )
        kwargs.update(custom_kwargs)
        super().__init__(
            xy, (x + dx, y),
            *args,
            arrowstyle='-',
            shrinkA=0.0,
            shrinkB=0.0,
            transform=ax.transAxes,
            **kwargs)
    def label(self,color,fontsize,**kwargs):
        (x0, y), (x1, _) = self._posA_posB
        if self._length.unit=='arcsec':
         s = "{0.value:g}$''$".format(self._length)
        else:
         s = "{0.value:g}{0.unit:unicode}".format(self._length)
        #print(s)
        #print(self._distance)
        #phys_size_kpc=
        #if self._distance.unit=='u.parsec':
        #    print("{0.value:g}".format(self._distance)) 
        d="{0.value:g}{0.unit:unicode}".format(self._distance)
        
        def angle_to_size(angle, distance): # angle in arcseconds
         size = (float(distance.value) * float(angle.value))/206265. * distance.unit
         return size
        
        physical_size_pc=angle_to_size(self._length,self._distance)
        physical_size_kpc=physical_size_pc.value/np.power(10,3)
        ps = '%.2f Kpc'%(physical_size_kpc)
        #ps = "{0.value:g}{0.unit:unicode}".format(physical_size)
        
        return (self._ax.text(0.5 * (x0 + x1), y, s,ha='center', va='bottom',color=color,fontsize=fontsize, transform=self._ax.transAxes, **kwargs),
                self._ax.text(0.5 * (x0 + x1), y-0.07, ps,ha='center', va='bottom',color=color,fontsize=fontsize, transform=self._ax.transAxes, **kwargs)) 
    
    
    
def scalebar(self, *args, **kwargs):
        """Add scale bar.
        Parameters
        ----------
        xy : tuple
            The axes coordinates of the scale bar.
        length : `astropy.units.Quantity`
            The length of the scale bar in angle-compatible units.
        Other parameters
        ----------------
        args :
            Extra arguments for `matplotlib.patches.FancyArrowPatch`
        kwargs :
            Extra keyword arguments for `matplotlib.patches.FancyArrowPatch`
        Returns
        -------
        patch : `matplotlib.patches.FancyArrowPatch`
        """
        return self.add_patch(ScaleBar(self, *args, **kwargs))
    
def crosshair(self, ra, dec, size, color,linewidth):
        """Add a cross hair at supernova postion."""
        sf=0.5
        gapsize=10
        
        ch1 = Quadrangle((ra,dec)*u.deg+(gapsize,0)*u.arcsec, size* u.arcsec,0* u.arcsec,lw=linewidth,
               edgecolor=color, facecolor='none',
               transform=ax1.get_transform('fk5'))
        ch2 = Quadrangle((ra,dec)*u.deg, 0* u.arcsec,sf*size* u.arcsec,lw=linewidth,
               edgecolor=color, facecolor='none',
               transform=ax1.get_transform('fk5'))
        return self.add_patch(ch1),self.add_patch(ch2)

# %%
#declaring position of the supernova, and in skycoord, and making cutouts (of each r,g,b)
sn_ra=309.33000691667
sn_dec=66.106417016667

sn_pos_coords = SkyCoord(ra=sn_ra*u.degree, dec=sn_dec*u.degree)
sn_pos=(sn_ra,sn_dec)*u.deg

#data1=hdu_img1.data
#data2=hdu_img2.data
#data3=hdu_img3.data

# make cutout 1 for rgb arrays, for now this is height and width in pixels
cutout1_height=15*u.arcsec
cutout1_width=15*u.arcsec

size_cutout1 = u.Quantity((cutout1_height, cutout1_width))
#position is (x,y)
#size is (ny,nx)
cutout1_r = Cutout2D(data1, sn_pos_coords, size_cutout1, wcs=wcs)
cutout1_g = Cutout2D(data2, sn_pos_coords, size_cutout1, wcs=wcs)
cutout1_b = Cutout2D(data3, sn_pos_coords, size_cutout1, wcs=wcs)
cutout1_stack=np.dstack((cutout1_r.data,cutout1_g.data,cutout1_b.data))

#make cutout 2

cutout2_height=2*u.arcsec
cutout2_width=2*u.arcsec
size_cutout2 = u.Quantity((cutout2_height, cutout2_width))

cutout2_r = Cutout2D(data1, sn_pos_coords, size_cutout2, wcs=wcs)
cutout2_g = Cutout2D(data2, sn_pos_coords, size_cutout2, wcs=wcs)
cutout2_b = Cutout2D(data3, sn_pos_coords, size_cutout2, wcs=wcs)
cutout2_stack=np.dstack((cutout2_r.data,cutout2_g.data,cutout2_b.data))

# %%
#way plot is configured, y is x and x is y (refer to compass)
fig = plt.figure(figsize=(15,10),facecolor='white')
gs = GridSpec(ncols=2, nrows=2, figure=fig,width_ratios=[2, 1],height_ratios=[1, 1])

ax1 = fig.add_subplot(gs[:,0],projection=wcs)
ax2 = fig.add_subplot(gs[0,1],projection=cutout1_r.wcs)
ax3 = fig.add_subplot(gs[1,1],projection=cutout2_r.wcs)

norm = ImageNormalize(stretch=SqrtStretch())

ax1.imshow(stack)
ax2.imshow(cutout1_stack)
ax3.imshow(cutout2_stack)

#Make circle
r = SphericalCircle((sn_pos), 6* u.arcsec,lw=1,
                     edgecolor='yellow', facecolor='none',
                     transform=ax1.get_transform('fk5'))
ax1.add_patch(r)

#make quadrangle 1, on main plot
#divide height by 2 to make square
width_q=cutout1_width
height_q=cutout1_height

sn_pos_qrect1 = ((sn_pos[0]) - (width_q), (sn_pos[1]) - (height_q/2)) * u.deg

q1 = Quadrangle((sn_pos_qrect1), width_q*2, height_q, edgecolor='green', facecolor='none', transform=ax1.get_transform('fk5'))
ax1.add_patch(q1)

#make circle 2, on first subplot
r2 = SphericalCircle((sn_pos), cutout2_height.value/2* u.arcsec,lw=1,
                     edgecolor='yellow', facecolor='none',
                     transform=ax2.get_transform('fk5'))
ax2.add_patch(r2)


#make quadrangle 2, on first subplot
width_q2=cutout2_width + 0.5*u.arcsec
height_q2= cutout2_height

sn_pos_qrect2 = ((sn_pos[0]) - (width_q2), (sn_pos[1]) - (height_q2/2)) * u.deg

q2 = Quadrangle((sn_pos_qrect2), width_q2*2, height_q2, edgecolor='green', facecolor='none', transform=ax2.get_transform('fk5'))
ax2.add_patch(q2)

#make circle 3, on second subplot
ellipse = Ellipse(xy=(25, 25), width=8, height=20, 
                        edgecolor='r', fc='None', lw=1)
ax3.add_patch(ellipse)



# add crosshair
ch_lenth,ch_width,ch_gap=0.3, 0.1, 0                   
x, y = wcs.world_to_pixel(SkyCoord(sn_pos[0],sn_pos[1], frame='fk5'))
#ax3.add_patch(Rectangle((x-ch_gap, y), -ch_lenth, ch_width))
#ax3.add_patch(Rectangle((x, y+ch_gap), ch_width, ch_lenth))
                         
compass(ax1,0.85,0.95,0.12,'white',30)
#add scalebar
#takes distance to galaxy in Mpc and calculated physical size
scalebar(ax1,(0.1, 0.1),20 * u.arcsec,23.250*np.power(10,6)*u.parsec,'white').label('white',30)# rounds to 2.25 instead of 2.24
scalebar(ax2,(0.1, 0.1),3 * u.arcsec,23.250*np.power(10,6)*u.parsec,'white').label('white',15)
scalebar(ax3,(0.1, 0.1),0.5 * u.arcsec,23.250*np.power(10,6)*u.parsec,'white').label('white',15)
norm = ImageNormalize(stretch=SqrtStretch())

ax1.set_xticklabels([])
ax1.set_ylabel('',fontsize=0)
ax1.set_xlabel('',fontsize=0)
ax1.tick_params(axis='both',labelsize=25)
ax1.tick_params(direction="in")
ax1.axis('off')
ax2.axis('off')
ax3.axis('off')

plt.subplots_adjust(wspace=-0.01)
plt.subplots_adjust(hspace=0.01)
#plt.subplots_adjust(left=0.04)
#plt.subplots_adjust(right=0.55)
#plt.subplots_adjust(top=1.0)
#plt.subplots_adjust(bottom=-0.3)
#ax1.text(0.6, 0.904, r'2022-2-17',transform=ax1.transAxes,verticalalignment='bottom',\
        # horizontalalignment='center',color='white', fontsize=35,fontname='font.serif  : cm')
#ax1.text(0.1, 0.3, 'HST/(F814W+555W)',transform=ax1.transAxes,verticalalignment='bottom',\
         #horizontalalignment='left',color='black', fontsize=25,fontname='font.serif  : cm',\
         #bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.1',alpha=0.9))
ax3.text(1.23, 0.25, 'S1',transform=ax1.transAxes,verticalalignment='bottom',\
         horizontalalignment='left',color='white', fontsize=25,fontname='font.serif  : cm')
#ax3.text(1.35, 0.05, '2021sjt',transform=ax1.transAxes,verticalalignment='bottom',\
        # horizontalalignment='left',color='white', fontsize=35,fontname='font.serif  : cm')
ax1.text(0.1, 0.9, 'NGC 6951', transform=ax1.transAxes, verticalalignment='bottom',
         horizontalalignment='left', color='white', fontsize=40)

#fig.text(0.45, 0.05, 'Right Ascension (J2000)', ha='center',fontsize=25)
#fig.text(0.1, 0.5, 'Declination (J2000)', va='center', rotation='vertical',fontsize=25)
plt.savefig('2021sjt_rgb_3_fig_plot_pre.png',dpi=300,bbox_inches='tight',transparent=False)
plt.show()
#change font to serif somehow, and then redo the plot for progenitor
#after that, run photometry on new datasets (got summary and gst full, figure out how to cut it then throw in the region file)

# %%
# Out:
# ...
#
# Note: you may need to restart the kernel to use updated packages.
